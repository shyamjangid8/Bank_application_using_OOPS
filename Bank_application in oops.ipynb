# %%
class Customer:
    """
    this class for every bank customer for open their account in bank 
    customer provide same detail like customername,acconutnumber,password,balance
    """
    acc_no = 1000
    def __init__(self,name,password,balance):
        self.name = name.strip().lower()
        self.password = password.strip().lower()
        self.balance = balance
        Customer.acc_no += 1
        self.account  = Customer.acc_no
    def __str__(self):
        return(f"{self.acc_no} => |{self.name}|{self.password}|{self.balance}|")

class Bank:
    account = 1000
    def __init__(self):
        self.record = {}
    def sign_account(self,customer):
        self.record[customer.acc_no]=[customer.name.lower(),customer.password.lower(),customer.balance]
    def login_account(self,account,password=None):
        if account in self.record.keys():
            if password in self.record.get(account):
                name = self.record[account][0]
                print(f"welcome back user! {name.title()}")
                return account
            else:
                print("!Error!Invalid Password!")
                print("Please Try Again")
                return False
        else:
            print("!Error! Invalid Account Number!")
            print("Please Check Account Number and Try Again!")
            print("Or just create new account by signing up!")
            return False
    def debit_balance(self,account,amount):
        if amount <= self.record[account][2]:
            self.record[account][2] -= amount
            print(f"!{amount}\u20B9!Sucessfully Debited from your account!")
            print(f"Your Remaining Balance is {self.record[account][2]}\u20B9.")
        else:
            print("!Error! In-sufficient Account Balance.")
            print(f"You only have {self.record[account][2]}\u20B9 in your account.")
    def credit_balance(self,account,amount):
        self.record[account][2] += amount
        print(f"!Your account sucessfully credited for {amount}\u20B9!")
        print(f"Your updated balance is {self.record[account][2]}\u20B9!")
    def cheak_balance(self,account):
        print(f"You have {self.record[account][2]}\u20B9 in your account.")

        

x = Bank()
x.sign_account(Customer("shubham","jangid",25000))
#     account = 1000
#     def __init__(self,name,password,balance):
#         self.name = name.strip().lower()
#         self.password = password.strip().lower()
#         self.balance = balance
#         Customer.account += 1
#         self.account  = Customer.account
#         self.record = {}
#     def sign_account(self):
#         self.record[self.account]=[self.name.lower(),self.password.lower(),self.balance]
x.sign_account(Customer("ram","sharma",50000))

x.record.keys()

x.login_account(1001,"jangid")

x.record

x.debit_balance(1001,5000)

x.cheak_balance(1001)

x.credit_balance(1001,5000)

x.debit_balance(1001,30000)


# class Bank:
# #     account = 1000
#     def __init__(self,name,password,balance):
#         self.name = name.strip().lower()
#         self.password = password.strip().lower()
#         self.balance = balance
# #         Customer.account += 1
# #         self.account  = Customer.account
# #         self.record = {}
#     def sign_account(self):
#         self.record[self.account]=[self.name.lower(),self.password.lower(),self.balance]
# Out:
# welcome back user! Shubham
# !5000₹!Sucessfully Debited from your account!
# Your Remaining Balance is 20000₹.
# You have 20000₹ in your account.
# !Your account sucessfully credited for 5000₹!
# Your updated balance is 25000₹!
# !Error! In-sufficient Account Balance.
# You only have 25000₹ in your account.

# %%
class Customer:
    """
    this class for every bank customer for open their account in bank 
    customer provide same detail like customername,acconutnumber,password,balance
    """
    acc_no = 1000
    def __init__(self,name,password,balance):
        self.name = name.strip().lower()
        self.password = password.strip().lower()
        self.balance = balance
        Customer.acc_no += 1
        self.account  = Customer.acc_no
    def __str__(self):
        return(f"{self.acc_no} => |{self.name}|{self.password}|{self.balance}|")

class Bank:
    def __init__(self):
        self.record = {}
    def sign_account(self, customer):
        self.record[customer.acc_no]=[customer.name.lower(),customer.password.lower(),customer.balance]
        print(f"your account  number is {customer.acc_no}!")
        return customer.acc_no
        
    def login_account(self,account,password=None):
        if account in self.record.keys():
            if password in self.record.get(account):
                name = self.record[account][0]
                print(f"welcome back user! {name.title()}")
                return account
            else:
                print("!Error!Invalid Password!")
                print("Please Try Again")
                return False
        else:
            print("!Error! Invalid Account Number!")
            print("Please Check Account Number and Try Again!")
            print("Or just create new account by signing up!")
            return False
        
    def debit_balance(self,account,amount):
        if amount <= self.record[account][2]:
            self.record[account][2] -= amount
            print(f"!{amount}\u20B9!Sucessfully Debited from your account!")
            print(f"Your Remaining Balance is {self.record[account][2]}\u20B9.")
        else:
            print("!Error! In-sufficient Account Balance.")
            print(f"You only have {self.record[account][2]}\u20B9 in your account.")
    def credit_balance(self,account,amount):
        self.record[account][2] += amount
        print(f"!Your account sucessfully credited for {amount}\u20B9!")
        print(f"Your updated balance is {self.record[account][2]}\u20B9!")
    def check_balance(self,account):
        print(f"You have {self.record[account][2]}\u20B9 in your account.")
        
    
def sub_menu(account):
    """
    Sub Menu for bank application
    """
    menu = """
    1. Debit
    2. Credit
    3. Check Balance
    4. Logout
    """
    while True:
        print(menu)
        ch = input("Choice: ")
        if ch == "1":
            amount = float(input("Enter Amount: "))
            x.debit_balance(account, amount)
        elif ch == "2":
            amount = float(input("Enter Amount: "))
            x.credit_balance(account, amount)
        elif ch == "3":
            x.check_balance(account)
        elif ch == "4":
            print("\n\nBye Bye See you Soon!\n")
            break
        else:
            print("\nInvalid Choice choose from 1, 2, 3 or 4")
            
def main_menu():
    """
    Main Menu for Bank Application
    """
    menu ="""
    1. Login
    2. Signup
    3. Exit
    """
    print(menu)
    ch = input("choice: ")
    if ch == "1":
        account = int(input("Enter account no:"))
        password = input("Enter password:")
        acc = x.login_account(account,password)
        print(acc)
        if acc:
            sub_menu(acc)
    elif ch == "2":
        name = input("Enter your name:").lower()
        password = input("Enter yuor password:").lower()
        balance = int(input("Enter your Balance:"))
        info = x.sign_account(Customer(name,password,balance))
        print(info)
    elif ch == "3":
        print("\n\nThanks for using Our Services\n\n")
        print("..................bye bye.........")
        exit(0)
    else:
        print("!Invalid Choice Please Select 1, 2, or 3!")


if __name__ == "__main__":
    x = Bank()
    while True:
#         os.system("cls")
        print("\n\n\n\n")
        print("Welcome to Python Bank".center(100))
        print("\n\n\n")
        main_menu()
        #time.sleep(10)
        input("\n\n\npress Enter to continue")
# Out:
#                                        Welcome to Python Bank
#
#
#
#
#
#     1. Login
#     2. Signup
#     3. Exit
#
# choice: 2
# Enter your name:shubham
# Enter yuor password:jangid
# Enter your Balance:4000
# your account  number is 1001!
# 1001
#
#
#
# press Enter to continue
#
#
#
#
#
#                                        Welcome to Python Bank
#
#
#
#
#
#     1. Login
#     2. Signup
#     3. Exit
#
# choice: 1
# Enter account no:1001
# Enter password:jangid
# welcome back user! Shubham
# 1001
#
#     1. Debit
#     2. Credit
#     3. Check Balance
#     4. Logout
#
# Choice: 3
# You have 4000₹ in your account.
#
#     1. Debit
#     2. Credit
#     3. Check Balance
#     4. Logout
#
# Choice: 2
# Enter Amount: 2000
# !Your account sucessfully credited for 2000.0₹!
# Your updated balance is 6000.0₹!
#
#     1. Debit
#     2. Credit
#     3. Check Balance
#     4. Logout
#
# Choice: 1
# Enter Amount: 3000
# !3000.0₹!Sucessfully Debited from your account!
# ...

# %%
x = Bank()

# %%
x.sign_account(Customer("shubham","jangid",250000))
# Out:
# 'your account  number is 1001!'

# %%
x.login_account(1001,"jangid")
# Out:
# welcome back user! Shubham
# 1001

# %%
c.get("name")
# Out:
# ['shubham', 'jangid', 98786555]

# %%
x = Customer("shubham","jangid",250000)
print(x)
# Out:
# 1006 => |shubham|jangid|250000|
